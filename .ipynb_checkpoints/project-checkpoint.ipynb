# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # load the dataset

# %%
data = pd.read_csv("sensor.csv")
data.head()
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# ...

# %%
data.tail()
# Out:
#         Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 220315      220315  2018-08-31 23:55:00   2.407350   47.69965  50.520830
# 220316      220316  2018-08-31 23:56:00   2.400463   47.69965  50.564240
# 220317      220317  2018-08-31 23:57:00   2.396528   47.69965  50.520830
# 220318      220318  2018-08-31 23:58:00   2.406366   47.69965  50.520832
# 220319      220319  2018-08-31 23:59:00   2.396528   47.69965  50.520832
#
#         sensor_03   sensor_04  sensor_05  sensor_06  sensor_07  ...  \
# 220315  43.142361  634.722229   64.59095   15.11863   16.65220  ...
# 220316  43.142361  630.902771   65.83363   15.15480   16.70284  ...
# 220317  43.142361  625.925903   67.29445   15.08970   16.70284  ...
# 220318  43.142361  635.648100   65.09175   15.11863   16.56539  ...
# 220319  43.142361  639.814800   65.45634   15.11863   16.65220  ...
#
#         sensor_43  sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  \
# ...

# %% [markdown]
# # basic details of the dataset

# %%
data.shape #dimensions of the data
# Out:
# (220320, 55)

# %% [markdown]
# Dataset contains total 220320 data points with 55 columns

# %%
data.columns #print the columns
# Out:
# Index(['Unnamed: 0', 'timestamp', 'sensor_00', 'sensor_01', 'sensor_02',
#        'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07',
#        'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12',
#        'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16', 'sensor_17',
#        'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21', 'sensor_22',
#        'sensor_23', 'sensor_24', 'sensor_25', 'sensor_26', 'sensor_27',
#        'sensor_28', 'sensor_29', 'sensor_30', 'sensor_31', 'sensor_32',
#        'sensor_33', 'sensor_34', 'sensor_35', 'sensor_36', 'sensor_37',
#        'sensor_38', 'sensor_39', 'sensor_40', 'sensor_41', 'sensor_42',
#        'sensor_43', 'sensor_44', 'sensor_45', 'sensor_46', 'sensor_47',
#        'sensor_48', 'sensor_49', 'sensor_50', 'sensor_51', 'machine_status'],
#       dtype='object')

# %% [markdown]
# Data contains readings from 52 sensors and corresponding time stamp with machine status

# %%
print(data['timestamp'])
# Out:
# 0         2018-04-01 00:00:00
# 1         2018-04-01 00:01:00
# 2         2018-04-01 00:02:00
# 3         2018-04-01 00:03:00
# 4         2018-04-01 00:04:00
#                  ...
# 220315    2018-08-31 23:55:00
# 220316    2018-08-31 23:56:00
# 220317    2018-08-31 23:57:00
# 220318    2018-08-31 23:58:00
# 220319    2018-08-31 23:59:00
# Name: timestamp, Length: 220320, dtype: object

# %% [markdown]
#   Sensor data of 5 months from April to August is provided.
#
#    Each row contains sensor readings after one minute.

# %%
print(data['machine_status'].unique())
# Out:
# ['NORMAL' 'BROKEN' 'RECOVERING']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220320 entries, 0 to 220319
# Data columns (total 55 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      220320 non-null  int64
#  1   timestamp       220320 non-null  object
#  2   sensor_00       210112 non-null  float64
#  3   sensor_01       219951 non-null  float64
#  4   sensor_02       220301 non-null  float64
#  5   sensor_03       220301 non-null  float64
#  6   sensor_04       220301 non-null  float64
#  7   sensor_05       220301 non-null  float64
#  8   sensor_06       215522 non-null  float64
#  9   sensor_07       214869 non-null  float64
#  10  sensor_08       215213 non-null  float64
#  11  sensor_09       215725 non-null  float64
#  12  sensor_10       220301 non-null  float64
#  13  sensor_11       220301 non-null  float64
#  14  sensor_12       220301 non-null  float64
#  15  sensor_13       220301 non-null  float64
# ...

# %% [markdown]
# From the timestamp, we can see that the data is recorded in 1-minute steps
#
#   the timestamp is in the yyyy-MM-dd HH:mm:ss format.

# %% [markdown]
# we can see many null values are present in the dataset and sensor 15 has no data
#
#   There are 2 object datatypes and 52 float64 datatypes

# %%
data.describe()
# Out:
#           Unnamed: 0      sensor_00      sensor_01      sensor_02  \
# count  220320.000000  210112.000000  219951.000000  220301.000000
# mean   110159.500000       2.372221      47.591611      50.867392
# std     63601.049991       0.412227       3.296666       3.666820
# min         0.000000       0.000000       0.000000      33.159720
# 25%     55079.750000       2.438831      46.310760      50.390620
# 50%    110159.500000       2.456539      48.133678      51.649300
# 75%    165239.250000       2.499826      49.479160      52.777770
# max    220319.000000       2.549016      56.727430      56.032990
#
#            sensor_03      sensor_04      sensor_05      sensor_06  \
# count  220301.000000  220301.000000  220301.000000  215522.000000
# mean       43.752481     590.673936      73.396414      13.501537
# std         2.418887     144.023912      17.298247       2.163736
# min        31.640620       2.798032       0.000000       0.014468
# ...

# %%
##since there is no use of column named 'unnamed:0' ,we drop that column

# %%
df=data.drop(['Unnamed: 0'],axis=1)

# %%
df.head()
# Out:
#              timestamp  sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  \
# 0  2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 1  2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2  2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570   638.8889
# 3  2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568   628.1250
# 4  2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568   636.4583
#
#    sensor_05  sensor_06  sensor_07  sensor_08  ...  sensor_43  sensor_44  \
# 0   76.45975   13.41146   16.13136   15.56713  ...   41.92708  39.641200
# 1   76.45975   13.41146   16.13136   15.56713  ...   41.92708  39.641200
# 2   73.54598   13.32465   16.03733   15.61777  ...   41.66666  39.351852
# 3   76.98898   13.31742   16.24711   15.69734  ...   40.88541  39.062500
# 4   76.58897   13.35359   16.21094   15.69734  ...   41.40625  38.773150
#
# ...

# %% [markdown]
# since sensor_15 contains no data values,we can drop the column

# %%
df.drop(['sensor_15'], axis=1, inplace=True)

# %%
#checking null values
df.isnull().sum()
# Out:
# timestamp             0
# sensor_00         10208
# sensor_01           369
# sensor_02            19
# sensor_03            19
# sensor_04            19
# sensor_05            19
# sensor_06          4798
# sensor_07          5451
# sensor_08          5107
# sensor_09          4595
# sensor_10            19
# sensor_11            19
# sensor_12            19
# sensor_13            19
# sensor_14            21
# sensor_16            31
# sensor_17            46
# sensor_18            46
# sensor_19            16
# sensor_20            16
# sensor_21            16
# sensor_22            41
# sensor_23            16
# sensor_24            16
# sensor_25            36
# sensor_26            20
# sensor_27            16
# sensor_28            16
# sensor_29            72
# sensor_30           261
# sensor_31            16
# sensor_32            68
# sensor_33            16
# sensor_34            16
# sensor_35            16
# sensor_36            16
# sensor_37            16
# ...

# %% [markdown]
# except machine status and timestamp column ,all other columns contain null values

# %% [markdown]
# # EDA

# %%
ax = sns.countplot(x=df['machine_status'],order=df['machine_status'].value_counts(ascending=False).index);

abs_values = df['machine_status'].value_counts(ascending=False).values

ax.bar_label(container=ax.containers[0], labels=abs_values)
sns.set()

# %% [markdown]
# Data contains 3 classes namely Normal, Recovering and Broken.
#
#   Normal contains 205836 data points,
#
#    Recovering contains 14477 data points,
#
#    and Broken contains 7 data points.

# %% [markdown]
# Let’s plot machine status as function of time

# %%
plt.plot(df['machine_status'])

# %% [markdown]
# From the above plot we can see that Recovering state follows Broken state.
#
#   In Recovering state pump is trying to recover from Broken state

# %%
##resample timestamp as a day
df['timestamp'] = pd.to_datetime(df['timestamp'])
df1 = df.set_index('timestamp') 
da = df1.resample(rule='D').mean()

# %% [markdown]
# mean of each sensor in each day from april to august

# %%
df2 = df1.drop(['machine_status'], axis=1)
names=df2.columns
import warnings
for name in names:
    warnings.filterwarnings("ignore")
    sns.set()
    _ = plt.figure(figsize=(9,5))
    _ = da[name].plot()
    _ = plt.title(name)

# %% [markdown]
# plot the means of the readings for each state of the pump and see how different the means are from one condition to another i.e. normal vs broken state.

# %%
normal = df[df['machine_status']=='NORMAL']
broken = df[df['machine_status']=='BROKEN']
recovering = df[df['machine_status']=='RECOVERING']

# %%
## Extract mean values of the sensor readings from the pump in all the states
means_normal=normal.mean(axis=0)
means_broken = broken.mean(axis=0)
means_recovering = recovering.mean(axis=0)

# %%
# Plot mean values of the sensor readings for each state of the pump

plt.figure(figsize=(18,9))
plt.plot(means_normal, marker='D', color='red', label='normal', linestyle='none')
plt.plot(means_broken, marker='D', color='blue', label='broken', linestyle='none')
plt.plot(means_recovering, marker='D', color='green', label='recovering', linestyle='none')
plt.xlabel('Sensors')
plt.ylabel('Mean Values')
plt.title('Means of the readings from each sensor')
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# some sensors have great difference in the means among each state
#
#   sensor_04,sensor_28,sensor_31 have great differences
